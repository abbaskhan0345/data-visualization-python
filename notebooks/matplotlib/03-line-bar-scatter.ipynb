# %% [markdown]
# # 📊 03 — Line, Bar, and Scatter Plots with Matplotlib
# **`03-line-bar-scatter.ipynb`**
#
# In this notebook, we’ll explore three of the **most commonly used plot types** in data visualization:
#
# * **Line Plots** → Great for trends over time
# * **Bar Plots** → Best for comparing categories
# * **Scatter Plots** → Useful for showing relationships between two variables
#
# We’ll use **Matplotlib** and **Seaborn’s `tips` dataset** to demonstrate each type.
#
# ---

# %% [markdown]
# ## 📌 1. Setup & Dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load sample dataset
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ---

# %% [markdown]
# ## 📈 2. Line Plots — Trends Over Time
#
# A **line plot** is useful when you want to see changes over a continuous variable (e.g., time, sequence, temperature).

# %%
# Example: Plotting total_bill trend by index
plt.figure(figsize=(8,5))
plt.plot(tips["total_bill"], color="blue", marker="o", linestyle="-")
plt.title("Line Plot of Total Bill")
plt.xlabel("Index")
plt.ylabel("Total Bill ($)")
plt.show()

# %% [markdown]
# 🔑 **Key Notes:**
#
# * `plt.plot()` → default line chart
# * `marker="o"` → adds dots to points
# * Line plots work best for continuous or ordered data
#
# 👉 Example usage: stock prices, monthly sales, temperature change
#
# ---

# %% [markdown]
# ## 📊 3. Bar Plots — Comparing Categories
#
# Bar plots show comparisons across **discrete categories**.

# %%
# Example: Average tip per day
avg_tips = tips.groupby("day")["tip"].mean()

plt.figure(figsize=(7,5))
plt.bar(avg_tips.index, avg_tips.values, color="orange")
plt.title("Average Tip by Day")
plt.xlabel("Day of Week")
plt.ylabel("Average Tip ($)")
plt.show()
# Out:
# C:\Users\hakha\AppData\Local\Temp\ipykernel_13108\831206607.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_tips = tips.groupby("day")["tip"].mean()

# %% [markdown]
# 🔑 **Key Notes:**
#
# * `plt.bar(categories, values)` for vertical bars
# * `plt.barh()` for horizontal bars
# * Perfect for categorical comparisons
#
# 👉 Example usage: sales per region, votes per candidate, website traffic per device
#
# ---

# %% [markdown]
# ## ⚪ 4. Scatter Plots — Relationship Between Two Variables
#
# Scatter plots are best when exploring **correlation** between variables.

# %%
# Example: Tip vs. Total Bill
plt.figure(figsize=(7,5))
plt.scatter(tips["total_bill"], tips["tip"], alpha=0.7, color="green")
plt.title("Scatter Plot: Total Bill vs Tip")
plt.xlabel("Total Bill ($)")
plt.ylabel("Tip ($)")
plt.show()

# %% [markdown]
# 🔑 **Key Notes:**
#
# * `plt.scatter(x, y)` creates scatter plots
# * `alpha` adds transparency to avoid overlap
# * Helpful for spotting **trends, outliers, clusters**
#
# 👉 Example usage: income vs. spending, hours studied vs. exam scores
#
# ---

# %% [markdown]
# ## 🎯 5. Comparison of Plot Types
#
# | Plot Type    | Best For                           |
# | ------------ | ---------------------------------- |
# | Line Plot    | Trends, continuous data            |
# | Bar Plot     | Comparing categories               |
# | Scatter Plot | Relationship between two variables |
#
# ---

# %% [markdown]
# # Bounus Extra
# ---

# %% [markdown]
# ## 🔹 . Line Plots

# %%
import numpy as np
# Sample data
x = np.arange(0, 10, 1)
y = x ** 2

plt.figure(figsize=(8,5))
plt.plot(x, y, color="blue", marker="o", linestyle="-", label="y = x^2")
plt.title("Line Plot Example")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 👉 **Explanation**:
# - `plt.plot()` creates the line graph.
# - We customized with `color`, `marker`, and `linestyle`.
# - `plt.legend()` helps clarify multiple lines.
# - Line plots are best when **tracking changes or trends**.
#
# ---

# %% [markdown]
# ## 🔹. Bar Plots

# %%
# Categories and values
categories = ["A", "B", "C", "D"]
values = [4, 7, 1, 8]

plt.figure(figsize=(7,5))
plt.bar(categories, values, color="orange")
plt.title("Bar Plot Example")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# 👉 **Explanation**:
# - `plt.bar()` creates vertical bars.
# - Useful for comparing discrete categories.
# - Bar height shows the **magnitude of values**.

# %% [markdown]
# ### Horizontal Bar Plot

# %%
plt.figure(figsize=(7,5))
plt.barh(categories, values, color="green")
plt.title("Horizontal Bar Plot Example")
plt.xlabel("Values")
plt.ylabel("Categories")
plt.show()

# %% [markdown]
# 👉 **Note**: Horizontal bars (`plt.barh`) are often better when category names are long.
#
# ---

# %% [markdown]
# ## 🔹. Scatter Plots

# %%
# Random scatter data
np.random.seed(42)
x = np.random.rand(50)
y = np.random.rand(50)

plt.figure(figsize=(7,5))
plt.scatter(x, y, color="purple", alpha=0.7, s=100, edgecolor="black")
plt.title("Scatter Plot Example")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.show()

# %% [markdown]
# 👉 **Explanation**:
# - `plt.scatter()` plots individual points.
# - Parameters:
#   - `alpha` → transparency
#   - `s` → size of markers
#   - `edgecolor` → outline around dots
# - Scatter plots are ideal for spotting **correlations or clusters**.
#
# ---

# %% [markdown]
# ## 🔹 . Comparing Multiple Lines

# %%
x = np.linspace(0, 10, 100)

plt.figure(figsize=(8,5))
plt.plot(x, np.sin(x), label="sin(x)", color="red")
plt.plot(x, np.cos(x), label="cos(x)", color="blue")
plt.title("Multiple Lines Example")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %% [markdown]
# 👉 Multiple lines in the same chart make it easy to compare trends or functions.
#
# ---

# %% [markdown]
# ## 📌 Summary
#
# ### What we learned:
# - **Line plots** → Show trends or continuous data.
# - **Bar plots** → Compare discrete categories (vertical or horizontal).
# - **Scatter plots** → Show relationships between two variables.
# - We also combined multiple lines on the same figure.
#
#
# ---
