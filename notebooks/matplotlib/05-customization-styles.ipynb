# %% [markdown]
# # 🎨 05 - Customization & Styles in Matplotlib
# **`05-customization-styles.ipynb`**
#
# Matplotlib is powerful not just for creating plots, but also for customizing them to make them **clear, aesthetic, and professional**.
# In this notebook, we’ll learn how to:
#
# - Add **titles, labels, legends, and annotations**.
# - Control **colors, markers, and line styles**.
# - Apply **Matplotlib stylesheets** for better visuals.
# - Adjust **figure size, grids, and background**.
# - Save figures in **different formats**.
#
# ---

# %% [markdown]
# ## 📌 1. Adding Titles, Labels, and Legends

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

plt.figure(figsize=(8,5))
plt.plot(x, y1, label="sin(x)", color="blue")
plt.plot(x, y2, label="cos(x)", color="red")

plt.title("Sine and Cosine Waves")
plt.xlabel("X-axis (radians)")
plt.ylabel("Y-axis (value)")
plt.legend()

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 📌 2. Colors, Line Styles, and Markers
# Matplotlib lets you customize almost every visual element.

# %%
plt.figure(figsize=(8,5))
plt.plot(x, y1, color="green", linestyle="--", marker="o", label="sin(x)")
plt.plot(x, y2, color="purple", linestyle="-.", marker="s", label="cos(x)")

plt.title("Custom Colors, Styles & Markers")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 📌 3. Grid and Axis Customization

# %%
plt.figure(figsize=(8,5))
plt.plot(x, y1, label="sin(x)")
plt.plot(x, y2, label="cos(x)")

plt.title("With Grid and Axis Customization")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()

# Enable grid
plt.grid(True, linestyle="--", alpha=0.6)

# Axis limits
plt.xlim(0, 10)
plt.ylim(-1.5, 1.5)

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 📌 4. Using Built-in Stylesheets
# Matplotlib comes with **predefined styles**.

# %%
print(plt.style.available)  # list of available styles
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
# Example: applying different styles
plt.style.use("ggplot")

plt.figure(figsize=(8,5))
plt.plot(x, y1, label="sin(x)")
plt.plot(x, y2, label="cos(x)")
plt.title("Styled with ggplot")
plt.legend()
plt.show()

# %%
# Another example
plt.style.use("seaborn-v0_8-dark-palette")

plt.figure(figsize=(8,5))
plt.plot(x, y1, label="sin(x)")
plt.plot(x, y2, label="cos(x)")
plt.title("Styled with seaborn-dark-palette")
plt.legend()
plt.show()

# %%
# Reset style
plt.style.use("default")

# %% [markdown]
# ---

# %% [markdown]
# ## 📌 5. Annotations
# Annotations allow us to **highlight specific points** in a plot.

# %%
plt.figure(figsize=(8,5))
plt.plot(x, y1, label="sin(x)")
plt.plot(x, y2, label="cos(x)")

plt.title("Adding Annotations Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()

# %%
# Annotate peak
peak_x = np.pi/2
peak_y = np.sin(peak_x)
plt.annotate("Peak of sin(x)", xy=(peak_x, peak_y), xytext=(2, 1),
             arrowprops=dict(facecolor="black", arrowstyle="->"))

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 📌 6. Saving Figures
# We can export plots in **PNG, JPG, SVG, PDF** and more.

# %%
plt.figure(figsize=(8,5))
plt.plot(x, y1, label="sin(x)")
plt.title("Saving Figure Example")
plt.legend()

# Save as PNG
plt.savefig("sine_plot.png", dpi=300)

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # ✅ Summary
#
# In this notebook, we covered:
#
# - Adding **titles, labels, and legends**.
# - Using **colors, line styles, and markers**.
# - Customizing **grids, axes, and figure size**.
# - Exploring **Matplotlib stylesheets**.
# - Highlighting data with **annotations**.
# - Exporting plots to **image files**.
#
#
# ---
