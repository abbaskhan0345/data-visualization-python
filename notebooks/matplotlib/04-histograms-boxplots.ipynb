# %% [markdown]
# # 📊 Histograms & Boxplots in Matplotlib
# **`04-histograms-boxplots.ipynb`**
#
# In this notebook, we’ll focus on **two fundamental types of statistical plots**:
#
# - **Histograms** → Great for showing the distribution (frequency) of a single variable.
# - **Boxplots** → Useful for understanding spread, outliers, and comparing distributions.
#
# ---

# %% [markdown]
# ## 🎯 Learning Objectives
# By the end of this notebook, you’ll be able to:
# - Create **histograms** with Matplotlib to analyze data distributions.
# - Customize bins, colors, and styles.
# - Build **boxplots** to identify spread, median, quartiles, and outliers.
# - Compare multiple groups using boxplots.
#
# ---

# %% [markdown]
# ## 📥 Importing Libraries & Dataset
# We’ll use the classic **Iris dataset** and a synthetic dataset for demonstration.

# %%
# Import libraries
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# # not important to this nootbook use just for downloading csv
# import pandas as pd
# from sklearn.datasets import load_iris
# data = load_iris()
# dir(data)

# df = pd.DataFrame(data.data, columns=data.feature_names)

# df2 = pd.DataFrame(data.target, columns=['type'])
# df1 = pd.concat([df, df2],axis=1)
# df1.drop(0, inplace=True)
# df1.to_csv('iris.csv')
# df1
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      type
# 1       0
# ...

# %%
# Load dataset
iris = pd.read_csv("/datasets/iris.csv")
iris.head()
# Out:
#    Unnamed: 0  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# 0           1                4.9               3.0                1.4
# 1           2                4.7               3.2                1.3
# 2           3                4.6               3.1                1.5
# 3           4                5.0               3.6                1.4
# 4           5                5.4               3.9                1.7
#
#    petal width (cm)  type
# 0               0.2     0
# 1               0.2     0
# 2               0.2     0
# 3               0.2     0
# 4               0.4     0

# %% [markdown]
# ---

# %% [markdown]
# ## 📈 Histograms – Understanding Distributions
#
# A **histogram** groups data into intervals (bins) and counts how many values fall into each bin.
# This is useful for seeing **data distribution** patterns.

# %%
# Histogram of petal length
plt.hist(iris["petal length (cm)"], bins=20, color="skyblue", edgecolor="black")
plt.title("Histogram of Petal Length")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### 🔧 Customizing Histograms
# - `bins` → number of intervals
# - `color` → bar fill
# - `edgecolor` → outline of bars
# - `alpha` → transparency

# %%
plt.hist(iris["sepal length (cm)"], bins=15, color="orange", alpha=0.7, edgecolor="black")
plt.title("Histogram of Sepal Width")
plt.xlabel("Sepal Width (cm)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 📦 Boxplots – Spread & Outliers
#
# A **boxplot** shows:
# - **Median (middle line)**
# - **Q1 & Q3 (box edges → interquartile range, IQR)**
# - **Whiskers (min & max within 1.5×IQR)**
# - **Outliers (points beyond whiskers)**

# %%
# Single variable boxplot
plt.boxplot(iris["petal length (cm)"])
plt.title("Boxplot of Petal Length")
plt.ylabel("Petal Length (cm)")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### 📊 Multiple Boxplots – Comparing Groups
#
# Boxplots are powerful for comparing distributions across **categories**.

# %%
# Grouped boxplot by species
species = iris["type"].unique()
data = [iris[iris["type"] == sp]["petal length (cm)"] for sp in species]

plt.boxplot(data, labels=species)
plt.title("Boxplot of Petal Length by Species")
plt.ylabel("Petal Length (cm)")
plt.show()
# Out:
# C:\Users\hakha\AppData\Local\Temp\ipykernel_16584\3875769680.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=species)

# %% [markdown]
# ---

# %%
# Sample dataset
np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=200)  # Normally distributed data

# %% [markdown]
# ---

# %% [markdown]
# ## 🔹 Histograms
# A **histogram** groups data into bins and shows the frequency (or probability density) of values.

# %%
plt.figure(figsize=(7,5))
plt.hist(data, bins=15, color='skyblue', edgecolor='black')
plt.title("Histogram of Data", fontsize=14)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 🔹 Boxplots
# A **boxplot** summarizes data using the median, quartiles (Q1, Q3), and potential outliers.

# %%
plt.figure(figsize=(7,3))
sns.boxplot(x=data, color="lightcoral")
plt.title("Boxplot of Data", fontsize=14)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 🔹 Side-by-Side Comparison
# To better understand the **distribution vs summary**, we plot a **histogram and boxplot together** for the same variable.

# %%
fig, axes = plt.subplots(2, 1, figsize=(8,6), sharex=True)

# Histogram
axes[0].hist(data, bins=15, color='skyblue', edgecolor='black')
axes[0].set_title("Histogram", fontsize=12)

# Boxplot
sns.boxplot(x=data, color="lightcoral", ax=axes[1])
axes[1].set_title("Boxplot", fontsize=12)

plt.suptitle("Histogram vs Boxplot", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 🔹 Multiple Distributions
# We can compare histograms and boxplots for different groups. Let’s create two datasets and compare.

# %%
# Two groups
group1 = np.random.normal(60, 8, 200)
group2 = np.random.normal(45, 12, 200)

# Side-by-side plots
fig, axes = plt.subplots(2, 2, figsize=(12,8))

# Histograms
axes[0,0].hist(group1, bins=15, color='skyblue', edgecolor='black')
axes[0,0].set_title("Histogram - Group 1")
axes[0,1].hist(group2, bins=15, color='lightgreen', edgecolor='black')
axes[0,1].set_title("Histogram - Group 2")

# Boxplots
sns.boxplot(x=group1, color="lightcoral", ax=axes[1,0])
axes[1,0].set_title("Boxplot - Group 1")
sns.boxplot(x=group2, color="orange", ax=axes[1,1])
axes[1,1].set_title("Boxplot - Group 2")

plt.suptitle("Histograms & Boxplots for Two Groups", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ✅ Summary
#
# - **Histograms**:
#   - Show frequency distribution of a variable.
#   - Controlled by **bins**, **colors**, and **styles**.
#
# - **Boxplots**:
#   - Show **median, quartiles, spread, and outliers**.
#   - Useful for comparing distributions across categories.
#
# 📌 With histograms, we **understand shape** of data; with boxplots, we **summarize spread and outliers**.
#
# - **Histograms** → Show *distribution shape* (normal, skewed, multimodal, etc.).
# - **Boxplots** → Highlight *median, spread, and outliers*.
# - **Together** → Provide both *visual intuition* and *statistical summary*.
#
# ---
