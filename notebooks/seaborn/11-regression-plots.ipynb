# %% [markdown]
# # 📈 Regression Plots in Seaborn
# **`11-regression-plots.ipynb`**
#
# Regression plots help visualize the **relationship between two variables** along with the fitted regression line.
# Seaborn provides **`regplot()`** for simple plots and **`lmplot()`** for advanced faceting and grouping.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load example dataset
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ Basic Regression Plot

# %%
sns.regplot(x="total_bill", y="tip", data=tips)
plt.title("Basic Regression Plot: Total Bill vs Tip")
plt.show()

# %% [markdown]
# ✅ Shows scatterplot + linear regression line.
#
# ---

# %% [markdown]
# ## 2️⃣ Regression with Confidence Interval

# %%
sns.regplot(x="total_bill", y="tip", data=tips, ci=95)
plt.title("Regression with Confidence Interval (95%)")
plt.show()

# %% [markdown]
# ✅ Shaded region = 95% confidence interval.
#
# ---

# %% [markdown]
# ## 3️⃣ Remove Confidence Interval

# %%
sns.regplot(x="total_bill", y="tip", data=tips, ci=None, color="red")
plt.title("Regression without Confidence Interval")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 4️⃣ Polynomial Regression

# %%
sns.regplot(x="total_bill", y="tip", data=tips, order=2, scatter_kws={"s": 40})
plt.title("Polynomial Regression (Order=2)")
plt.show()

# %% [markdown]
# ✅ Fits a quadratic curve instead of a straight line.
#
# ---

# %% [markdown]
# ## 5️⃣ Logistic Regression

# %%
# Example: smoker vs tip > 3 (binary outcome)
tips["big_tip"] = (tips["tip"] > 3).astype(int)

sns.regplot(x="total_bill", y="big_tip", data=tips, logistic=True, ci=None)
plt.title("Logistic Regression: Probability of Big Tip")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 4
#       1 # Example: smoker vs tip > 3 (binary outcome)
#       2 tips["big_tip"] = (tips["tip"] > 3).astype(int)
# ----> 4 sns.regplot(x="total_bill", y="big_tip", data=tips, logistic=True, ci=None)
#       5 plt.title("Logistic Regression: Probability of Big Tip")
#       6 plt.show()
#
# File c:\Users\hakha\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\regression.py:775, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     773 scatter_kws["marker"] = marker
#     774 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 775 plotter.plot(ax, scatter_kws, line_kws)
#     776 return ax
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 6️⃣ lmplot for Grouped Regression

# %%
sns.lmplot(x="total_bill", y="tip", hue="sex", data=tips, height=5, aspect=1.2)
plt.title("lmplot: Regression by Sex")
plt.show()

# %% [markdown]
# ✅ Automatically separates regressions by group (`hue`).
#
# ---

# %% [markdown]
# ## 7️⃣ Faceted lmplot

# %%
sns.lmplot(x="total_bill", y="tip", col="sex", row="smoker", data=tips, height=4)

# %% [markdown]
# ✅ Creates multiple regression plots across **rows & columns**.
#
# ---

# %% [markdown]
# ## 8️⃣ Style Customization

# %%
sns.lmplot(
    x="total_bill", y="tip", hue="day", data=tips,
    palette="Set1", markers=["o", "s", "D", "^"],
    height=5, aspect=1.3
)
plt.title("Custom Styled Regression by Day")
plt.show()

# %% [markdown]
# ---
#
# # 📌 Summary
#
# - **regplot()** → simple regression (with optional polynomial & logistic fits).
# - **lmplot()** → regression with grouping & faceting.
# - **Customization** → control scatter style, colors, markers, and layout.
#
# ---
