# %% [markdown]
# # 🔢 Matrix Plots in Seaborn
# **`10-matrix-plots.ipynb`**
#
# Matrix plots are useful for visualizing **relationships between multiple variables** in a grid-like form.
# Seaborn provides **heatmap** and **clustermap** to explore correlations and clustered structures.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Load dataset
flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ Heatmap (Basic)

# %%
# ✅ Correct pivot
flights_pivot = flights.pivot(index="month", columns="year", values="passengers")

# Heatmap
sns.heatmap(flights_pivot, annot=True, fmt="d", cmap="YlGnBu")
plt.title("Flights Heatmap: Passengers per Month-Year")
plt.show()

# %% [markdown]
# ✅ Each cell = number of passengers for that month & year.
#
# ---

# %% [markdown]
# ## 2️⃣ Correlation Heatmap

# %%
# Compute correlation matrix (numeric columns only)
corr = iris.corr(numeric_only=True)

# Heatmap with colorbar
sns.heatmap(corr, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap - Iris Dataset")
plt.show()

# %% [markdown]
# ✅ Highlights correlations between numerical variables.
#
# ---

# %% [markdown]
# ## 3️⃣ Masked Heatmap

# %%
# Generate mask for upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

sns.heatmap(corr, mask=mask, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Masked Correlation Heatmap")
plt.show()

# %% [markdown]
# ✅ Useful to avoid redundancy in symmetric matrices.
#
# ---

# %% [markdown]
# ## 4️⃣ Cluster Map (Hierarchical Clustering)

# %%
sns.clustermap(corr, annot=True, cmap="viridis", linewidths=0.5)

# %% [markdown]
# ✅ Automatically **clusters similar variables** together.
#
# ---

# %% [markdown]
# ## 5️⃣ Heatmap with Custom Styling

# %%
sns.heatmap(flights_pivot, annot=False, cmap="magma", cbar=True, linewidths=1, linecolor="white")
plt.title("Styled Flights Heatmap")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 📌 Summary
#
# - **Heatmap** → color-coded matrix of values
# - **Correlation Heatmap** → visualize variable correlations
# - **Masked Heatmap** → show only half of a symmetric matrix
# - **Cluster Map** → hierarchical clustering of variables
# - **Custom Styling** → improve readability & aesthetics
#
# ---
