# %% [markdown]
# # 📊 Distribution Plots in Seaborn
# **`08-distribution-plots.ipynb`**
#
# Seaborn provides powerful tools for **visualizing distributions** of data.
# These plots are useful for understanding **spread, central tendency, and outliers**.
#
# We’ll use the `tips` dataset for demonstration.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ Histogram (`histplot`)

# %%
sns.histplot(tips["total_bill"], bins=20, kde=False)
plt.title("Histogram of Total Bill")
plt.show()

# %% [markdown]
# ✅ Shows **frequency distribution**.
#
# ---

# %% [markdown]
# ## 2️⃣ Histogram + KDE Overlay

# %%
sns.histplot(tips["total_bill"], bins=20, kde=True)
plt.title("Histogram with KDE (Kernel Density Estimate)")
plt.show()

# %% [markdown]
# ✅ KDE curve shows **smoothed distribution**.
#
# ---

# %% [markdown]
# ## 3️⃣ Kernel Density Plot (`kdeplot`)

# %%
sns.kdeplot(tips["total_bill"], shade=True)
plt.title("KDE Plot of Total Bill")
plt.show()
# Out:
# C:\Users\hakha\AppData\Local\Temp\ipykernel_15664\1866822056.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips["total_bill"], shade=True)

# %% [markdown]
# ✅ KDE is a **smooth curve** estimate of the probability distribution.
#
# ---

# %% [markdown]
# ## 4️⃣ Cumulative Distribution

# %%
sns.kdeplot(tips["total_bill"], cumulative=True, shade=True)
plt.title("Cumulative Distribution of Total Bill")
plt.show()
# Out:
# C:\Users\hakha\AppData\Local\Temp\ipykernel_15664\1274098141.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips["total_bill"], cumulative=True, shade=True)

# %% [markdown]
# ✅ Helps visualize **proportion of data below a threshold**.
#
# ---

# %% [markdown]
# ## 5️⃣ Rug Plot

# %%
sns.rugplot(tips["total_bill"])
plt.title("Rug Plot of Total Bill")
plt.show()

# %% [markdown]
# ✅ Rug plots show **individual observations** along an axis.
#
# ---

# %% [markdown]
# ## 6️⃣ Multiple Distributions

# %%
sns.histplot(data=tips, x="total_bill", hue="sex", kde=True, element="step")
plt.title("Distribution by Gender")
plt.show()

# %% [markdown]
# ✅ Compare distributions across categories.
#
# ---

# %% [markdown]
# ## 7️⃣ Joint Distribution (`jointplot`)

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="scatter")
plt.show()

# %% [markdown]
# ✅ Displays **bivariate relationships** with marginal distributions.
#
# Other `kind` options: `"kde"`, `"hex"`, `"reg"`.
#
# ---

# %% [markdown]
# ## 8️⃣ Pairwise Distributions (`pairplot`)

# %%
sns.pairplot(tips, hue="sex")
plt.show()

# %% [markdown]
# ✅ Shows **relationships between all numerical variables**.
#
# ---

# %% [markdown]
# # 📌 Summary
#
# - ✅ **`histplot`** → histograms with optional KDE
# - ✅ **`kdeplot`** → smooth distribution curve
# - ✅ **`rugplot`** → raw data points
# - ✅ **`jointplot`** → bivariate distribution
# - ✅ **`pairplot`** → multiple pairwise distributions
#
# ---
