# %% [markdown]
# # 📊 Categorical Plots in Seaborn
# **`09-categorical-plots.ipynb`**
#
# Categorical plots are used to **compare categories** rather than continuous distributions.
# Seaborn provides multiple tools to visualize **counts, proportions, and category-wise distributions**.
#
# We’ll use the `tips` dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ---
#
# ## 1️⃣ Bar Plot (`barplot`)

# %%
sns.barplot(x="sex", y="total_bill", data=tips, estimator=sum, ci=None)
plt.title("Total Bill by Gender")
plt.show()
# Out:
# C:\Users\hakha\AppData\Local\Temp\ipykernel_16824\165965638.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="sex", y="total_bill", data=tips, estimator=sum, ci=None)

# %% [markdown]
# ✅ By default, `barplot` shows the **mean** with confidence interval.
# Here we set `estimator=sum` to see total bill instead.
#
# ---

# %% [markdown]
# ## 2️⃣ Count Plot (`countplot`)

# %%
sns.countplot(x="day", data=tips, hue="sex")
plt.title("Count of Customers by Day and Gender")
plt.show()

# %% [markdown]
# ✅ Shows the **number of observations** per category.
#
# ---

# %% [markdown]
# ## 3️⃣ Box Plot (`boxplot`)

# %%
sns.boxplot(x="day", y="total_bill", data=tips, hue="sex")
plt.title("Boxplot of Total Bill by Day and Gender")
plt.show()

# %% [markdown]
# ✅ Boxplots display **median, quartiles, and outliers**.
#
# ---

# %% [markdown]
# ## 4️⃣ Violin Plot (`violinplot`)

# %%
sns.violinplot(x="day", y="total_bill", data=tips, hue="sex", split=True)
plt.title("Violin Plot of Total Bill by Day")
plt.show()

# %% [markdown]
# ✅ Combines a **boxplot + KDE distribution**.
#
# ---

# %% [markdown]
# ## 5️⃣ Strip Plot (`stripplot`)

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True)
plt.title("Strip Plot of Total Bill by Day")
plt.show()

# %% [markdown]
# ✅ Shows **individual data points** with some jitter to reduce overlap.
#
# ---

# %% [markdown]
# ## 6️⃣ Swarm Plot (`swarmplot`)

# %%
sns.swarmplot(x="day", y="total_bill", data=tips, hue="sex")
plt.title("Swarm Plot of Total Bill by Day and Gender")
plt.show()

# %% [markdown]
# ✅ Like a strip plot but prevents overlap → **denser, more readable**.
#
# ---

# %% [markdown]
# ## 7️⃣ Combined Categorical Plots

# %%
sns.violinplot(x="day", y="total_bill", data=tips, inner=None, color="lightgray")
sns.swarmplot(x="day", y="total_bill", data=tips, hue="sex", dodge=True)
plt.title("Violin + Swarm Plot")
plt.show()

# %% [markdown]
# ✅ Overlaying plots gives deeper insights.
#
# ---

# %% [markdown]
# # 📌 Summary
#
# - **Bar Plot** → category means (or other stats with `estimator`)
# - **Count Plot** → frequency counts
# - **Box Plot** → quartiles + outliers
# - **Violin Plot** → KDE + box info
# - **Strip/Swarm Plot** → individual data points
#
# ---
