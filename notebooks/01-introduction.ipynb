# %% [markdown]
# # 📘 `01-introduction.ipynb`
# **`01-introduction.ipynb`**
#
# # 🖼️ Introduction to Data Visualization in Python
#
# Welcome!
# In this notebook, we’ll introduce **data visualization** — why it matters, how it helps in data science, and which tools we’ll use in Python.
#
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 🏁 What is Data Visualization?
#
# Data visualization is the process of **turning raw data into visual insights** using charts, graphs, and plots.
#
# It helps:
# - Identify **patterns, trends, and outliers**.
# - Communicate findings to both technical and non-technical audiences.
# - Support **data-driven decision making**.
#
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 🎯 Why Does It Matter?
#
# Raw data can be overwhelming 👇
#
# | Name | Sales | Month |
# |------|-------|-------|
# | A    | 120   | Jan   |
# | B    | 90    | Jan   |
# | A    | 150   | Feb   |
# | B    | 130   | Feb   |
#
# But when visualized:

# %%
import matplotlib.pyplot as plt

months = ["Jan", "Feb"]
sales_A = [120, 150]
sales_B = [90, 130]

plt.plot(months, sales_A, marker='o', label="A")
plt.plot(months, sales_B, marker='o', label="B")
plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 📊 Types of Visualizations
#
# - **Univariate** → histograms, bar charts
# - **Bivariate** → scatterplots, line plots
# - **Multivariate** → heatmaps, pairplots
# - **Advanced** → interactive dashboards
#
# We’ll explore all of these step by step.
#
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 🛠 Python Libraries for Visualization
#
# We’ll use three key libraries:
#
# 1. **Matplotlib** → low-level, very flexible plotting library.
# 2. **Seaborn** → built on Matplotlib, provides beautiful statistical plots.
# 3. **Plotly** → interactive visualizations (we’ll explore later).

# %%
# Quick preview of each library

import seaborn as sns
import pandas as pd

# Simple dataset
tips = sns.load_dataset("tips")

# Matplotlib
tips["total_bill"].plot(kind="hist", bins=20, title="Matplotlib Example")
plt.show()

# Seaborn
sns.histplot(data=tips, x="total_bill", bins=20)
plt.title("Seaborn Example")
plt.show()

# Plotly
import plotly.express as px
fig = px.histogram(tips, x="total_bill", nbins=20, title="Plotly Example")
fig.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 📂 Datasets in This Repository
#
# We’ll work with a few datasets stored in the `datasets/` folder:
#
# - **sales.csv** → sample company sales records
# - **tips.csv** → restaurant tips dataset
# - **iris.csv** → flower dataset for classification tasks
#
# Each notebook will use one or more of these.
#
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 🚀 Roadmap of This Repository
#
# Here’s the journey we’ll follow:
#
# 1. **Introduction** (this notebook)
# 2. **Matplotlib Basics** → simple plots
# 3. **Seaborn Basics & Advanced** → prettier, statistical plots
# 4. **Plotly** → interactive visualizations
# 5. **Mini Projects & Case Studies** → combine everything
#
# ---

# %%
# (Optional visualization of roadmap with matplotlib)
steps = ["Intro", "Matplotlib", "Seaborn", "Plotly", "Projects"]
y = [5, 4, 3, 2, 1]

plt.figure(figsize=(8,4))
plt.plot(steps, y, marker="o")
plt.gca().invert_yaxis()
plt.title("Visualization Roadmap")
plt.xlabel("Learning Steps")
plt.ylabel("Progress Level")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 📌 Summary
#
# - Data visualization is **essential** for understanding and communicating data.
# - Python offers powerful libraries: **Matplotlib, Seaborn, and Plotly**.
# - This repo will guide you step by step from **basics → advanced → projects**.
#
# ---
